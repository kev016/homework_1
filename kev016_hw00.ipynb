# %% [markdown]
# # Знакомство с SymPy

# %% [markdown]
# ### Индивидуальное домашнее задание

# %% [markdown]
# ### Катаев Евгений Владимирович (kev016), группа: М21-106

# %% [markdown]
# **Выполните указанные ниже действия, сохраните свою работу в виде ipynb-файла с именем `kev016_hw00.ipynb` и прикрепите этот файл к сообщению своему преподавателю**.

# %% [markdown]
# **Задание 1.** Вычислите значение выражения $\displaystyle\ln\left(\frac{\sqrt2}{{(\cos2+3)}^2{(\log_38+2)}^3}+\sqrt[5]{e^2}\right)$ с точностью 40 значащих десятичных цифр.

# %%
from sympy import *
init_printing()
# %matplotlib inline
log(sqrt(2)/((cos(2)+3)**2*(log(8, 3)+2)**3)+E**(S(2)/5)).evalf(40)
# Out:
# 0.4024041231583670858159584104348583781566

# %% [markdown]
# **Задание 2.** Раскройте скобки в выражении $\left(x - y\right)^{2} \left(2 x - y\right)^{3} \left(u + 2 z - 1\right)$.

# %%
var('x y u z')
expand((x-y)**2*(2*x-y)**3*(u+2*z-1))
# Out:
#      5         4           3  2         2  3          4      5       5
# 8⋅u⋅x  - 28⋅u⋅x ⋅y + 38⋅u⋅x ⋅y  - 25⋅u⋅x ⋅y  + 8⋅u⋅x⋅y  - u⋅y  + 16⋅x ⋅z - 8⋅x
#
# 5       4           4         3  2         3  2       2  3         2  3
#   - 56⋅x ⋅y⋅z + 28⋅x ⋅y + 76⋅x ⋅y ⋅z - 38⋅x ⋅y  - 50⋅x ⋅y ⋅z + 25⋅x ⋅y  + 16⋅x
#
#   4          4      5      5
# ⋅y ⋅z - 8⋅x⋅y  - 2⋅y ⋅z + y

# %% [markdown]
# **Задание 3.** Разложите на множители многочлен $3 u^{3} x^{2} + 12 u^{3} x y + 12 u^{3} y^{2} + u^{2} x^{3} + 4 u^{2} x^{2} y + 6 u^{2} x^{2} z + 4 u^{2} x y^{2} + 24 u^{2} x y z + 24 u^{2} y^{2} z + 2 u x^{3} z + 8 u x^{2} y z + 3 u x^{2} z^{2} + 8 u x y^{2} z + 12 u x y z^{2} + 12 u y^{2} z^{2} + x^{3} z^{2} + 4 x^{2} y z^{2} + 4 x y^{2} z^{2}$.

# %%
factor(3*u**3*x**2 + 12*u**3*x*y + 12*u**3*y**2 + u**2*x**3 + 4*u**2*x**2*y + 6*u**2*x**2*z + 4*u**2*x*y**2 + 24*u**2*x*y*z + 24*u**2*y**2*z + 2*u*x**3*z + 8*u*x**2*y*z + 3*u*x**2*z**2 + 8*u*x*y**2*z + 12*u*x*y*z**2 + 12*u*y**2*z**2 + x**3*z**2 + 4*x**2*y*z**2 + 4*x*y**2*z**2)
# Out:
#        2                    2
# (u + z) ⋅(3⋅u + x)⋅(x + 2⋅y)

# %% [markdown]
# **Задание 4.** Найдите действительные корни уравнения $35 x^{4} + 33 x^{3} + 242 x^{2} - 15 x - 7 = 0$.

# %%
solveset(35*x**4 + 33*x**3 + 242*x**2 - 15*x - 7, x, domain = S.Reals)
# Out:
# {-1/7, 1/5}

# %% [markdown]
# **Задание 5.** Постройте график функции, заданной неявно: $\displaystyle 3 x - \left|{y}\right| + \left|{3 x + y}\right|=0$. Используйте одинаковый масштаб по координатным осям.

# %%
plot_implicit(3*x - Abs(y) + Abs(3*x + y), aspect_ratio = (1, 1), line_color = 'cyan')

# %% [markdown]
# **Задание 6.** Постройте график функции, заданной параметрически: $\displaystyle x(t)=3 \sin{\left (4 t \right )}$, $\displaystyle y(t)=6 \sin{\left (3 t \right )}$. Используйте минимальный по длине промежуток изменения параметра и одинаковый масштаб по координатным осям.

# %%
var('t')
plotting.plot_parametric(3*sin(4*t), 6*sin(3*t), (t, 0, 2*pi),  aspect_ratio = (1, 1))
